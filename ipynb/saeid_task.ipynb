# %%
import sys
import datetime as dt
from pathlib import Path
from collections import OrderedDict
import math

import requests
import gtfstk as gt
from highcharts import Highchart 

DIR = Path('..')
sys.path.append(str(DIR))
from transit_reliability import *

# %load_ext autoreload
# %autoreload 2

TESTS_DIR = DIR/'tests'/'data'
DATA_DIR = DIR/'data'/'auckland'

# %%
#dates = ['20160513', '20160514', '20160515', '20160516', '20160517', '20160518', '20160519']
date = '20160519'

# %%
# Load GTFS feed to access scheduling data
#feed = gt.read_gtfs(DATA_DIR/'auckland_gtfs_20160511.zip', dist_units_in='km') # Good till 20160518
feed = gt.read_gtfs(DATA_DIR/'auckland_gtfs_20160519.zip', dist_units_in='km') # Good from 20160519

# %%
# Clean delays and combine them for the entire date range
delays = pd.read_csv(DATA_DIR/'delays_{0}.csv.gz'.format(date), 
  compression='gzip', dtype={'stop_id': str, 'stop_sequence': int})

# Concatenate delays and stop times
f = gt.get_stop_times(feed, date)
f = f.merge(delays, how='left')

# Write to file
path = DATA_DIR/'augmented_stop_times_{0}.csv.gz'.format(date)
f.to_csv(str(path), index=False, compression='gzip')

f.T
# Out:
#                                                0       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:00:00
# departure_time                               07:00:00
# stop_id                                          6920
# stop_sequence                                       1
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                                 0
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                1       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:02:10
# departure_time                               07:02:10
# stop_id                                          6800
# stop_sequence                                       2
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                            1.1846
# arrival_delay                                     NaN
# departure_delay                                   108
#
#                                                2       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:02:20
# departure_time                               07:02:20
# stop_id                                          6364
# stop_sequence                                       3
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                            1.4745
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                3       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:02:30
# departure_time                               07:02:30
# stop_id                                          6366
# stop_sequence                                       4
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           1.74088
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                4       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:02:40
# departure_time                               07:02:40
# stop_id                                          6182
# stop_sequence                                       5
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           2.01381
# arrival_delay                                     NaN
# departure_delay                                   151
#
#                                                5       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:03:03
# departure_time                               07:03:03
# stop_id                                          6156
# stop_sequence                                       6
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           2.28962
# arrival_delay                                     200
# departure_delay                                   208
#
#                                                6       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:03:28
# departure_time                               07:03:28
# stop_id                                          6319
# stop_sequence                                       7
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           2.88646
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                7       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:03:38
# departure_time                               07:03:38
# stop_id                                          6306
# stop_sequence                                       8
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           3.13798
# arrival_delay                                     NaN
# departure_delay                                   337
#
#                                                8       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:03:46
# departure_time                               07:03:46
# stop_id                                          6308
# stop_sequence                                       9
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           3.45216
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                9       \
# trip_id              1000015308-20160512154122_v40.34
# arrival_time                                 07:04:02
# departure_time                               07:04:02
# stop_id                                          6313
# stop_sequence                                      10
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                     NaN
# shape_dist_traveled                           3.65087
# arrival_delay                                     376
# departure_delay                                   398
#
#                                    ...                 \
# trip_id                            ...
# arrival_time                       ...
# departure_time                     ...
# stop_id                            ...
# stop_sequence                      ...
# stop_headsign                      ...
# pickup_type                        ...
# drop_off_type                      ...
# shape_dist_traveled                ...
# arrival_delay                      ...
# departure_delay                    ...
#
#                                                334149  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:48:15
# departure_time                               12:48:15
# stop_id                                          8418
# stop_sequence                                      16
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           6.34519
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334150  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:49:28
# departure_time                               12:49:28
# stop_id                                          8420
# stop_sequence                                      17
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                            6.7551
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334151  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:50:41
# departure_time                               12:50:41
# stop_id                                          8422
# stop_sequence                                      18
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           7.11309
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334152  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:51:54
# departure_time                               12:51:54
# stop_id                                          8424
# stop_sequence                                      19
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           7.32066
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334153  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:53:07
# departure_time                               12:53:07
# stop_id                                          8426
# stop_sequence                                      20
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           7.71901
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334154  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:54:20
# departure_time                               12:55:00
# stop_id                                          8428
# stop_sequence                                      21
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           8.00679
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334155  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:55:30
# departure_time                               12:55:30
# stop_id                                          8430
# stop_sequence                                      22
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           8.40636
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334156  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 12:56:00
# departure_time                               12:56:00
# stop_id                                          8432
# stop_sequence                                      23
# stop_headsign                                     NaN
# pickup_type                                       NaN
# drop_off_type                                       1
# shape_dist_traveled                           8.62261
# arrival_delay                                     NaN
# departure_delay                                   NaN
#
#                                                334157  \
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 13:25:00
# departure_time                               13:25:00
# stop_id                                          2006
# stop_sequence                                      24
# stop_headsign                                     NaN
# pickup_type                                         1
# drop_off_type                                     NaN
# shape_dist_traveled                           23.0881
# arrival_delay                                   -1291
# departure_delay                                   NaN
#
#                                                334158
# trip_id              8300032432-20160512154122_v40.34
# arrival_time                                 13:30:00
# departure_time                               13:30:00
# stop_id                                          2010
# stop_sequence                                      25
# stop_headsign                                     NaN
# pickup_type                                         1
# drop_off_type                                     NaN
# shape_dist_traveled                           24.2706
# arrival_delay                                    -852
# departure_delay                                   NaN
#
# [11 rows x 334159 columns]

# %%
a = f['delay'].count()
b = f['delay'].shape[0]
print(a, b, a/b)
# Out:
# 182772 334159 0.546961177164

# %%
# # Merge scheduled and actual stop times for study date
# g = pd.read_csv(DATA_DIR/'gtfsr_stop_times_{0}.csv.gzip'.format(date), 
#   compression='gzip', dtype={'stop_id': str})
# del g['route_id']

# st = st.merge(g, how='left').sort_values(['trip_id', 'stop_sequence'])


# print('study date is', date)
# print('num scheduled stop times =', st.shape[0])
# print('num arrival delays=', st['arrival_delay'].count())
# print('num departure delays=', st['departure_delay'].count())
# print('num delays=', st['delay'].count())

# %%
# Compute trips stats for later
ts = gt.compute_trips_stats(feed)
# rs = gt.compute_routes_stats(feed, ts, date)
# rs = rs.merge(feed.routes[['route_id', 'route_long_name']])

# %% [markdown]
# # Tukey box plots of stop delays by route

# %%
def agg_tukey(group):
    s = dict()
    dcol = 'delay'
    for i in range(1, 4):
        col = 'delay_q{0}'.format(i)
        s[col] = group[dcol].dropna().quantile(i/4)
          
    iqr = s['delay_q3'] - s['delay_q1']
    s['iqr'] = iqr
    cond = group[dcol] <= s['delay_q3'] + 1.5*iqr
    s['delay_high'] = group.loc[cond, dcol].max()
    cond = group[dcol] >= s['delay_q1'] - 1.5*iqr
    s['delay_low'] = group.loc[cond, dcol].min()
    s['num_delays'] = group[dcol].count()
    s['num_realtime_runs'] = (group['trip_id'] + group['date']).nunique()
    s['num_unique_trip_ids'] = group['trip_id'].nunique()
    return pd.Series(s)

f = all_delays.copy()
f = f.groupby('route_id').apply(agg_tukey).reset_index()
f = f.merge(feed.routes)
f.head()

# Only keep routes with an average of at least k delay samples per sample trip
k = 3
cond = f['num_delays']/f['num_realtime_runs'] >= k
g = f[cond].copy()

# Convert to minutes
box_cols = ['delay_low', 'delay_q1', 'delay_q2', 'delay_q3', 'delay_high']
g[box_cols] /= 60
g['route_name'] = g[['route_short_name', 'route_long_name']].apply(
  lambda x: ', '.join(x), axis=1) 

# Print 10 biggest IQR routes
print('Routes with largest IQR:')
print(g.sort_values('iqr', ascending=False).head(5))

# Plot
chart = Highchart()
data = g[['route_name'] + box_cols].copy()
chart.add_data_set(data.values.tolist(), series_type='boxplot')
N = data.shape[0]
date_range = ', '.join(dates)        
    
options = {
    'chart': {
        'height': 15*N,
        'inverted': True,
    },
    'plotOptions': {
    },
    'title': {
        'text': 'Tukey box plots of stop delays by route',
    },
    'subtitle': {
        'text': 'Sample period is {0}'.format(date_range)
    },
    'legend': {
        'enabled': False,
    },
    'xAxis': {
        'title': {
            'text': 'Route'
        },
        'type': 'category',
        'labels': {'step': 1},
    },
    'yAxis': {
        'title': {
            'text': 'Minutes'
        },
        'opposite': True,
        'plotLines': [{
            'value': 0,
            'color': 'red',
            'width': 2,
        }]    
    },
    'tooltip': {
#         'formatter': 'function () {\
#             return this.point.q3 - this.point.q1 + " min"\
#         }',
        'valueDecimals': 1,
        'headerFormat': '<b>{point.key}</b><br/>',
        'pointFormat': 'low: {point.low} min<br/>'\
          'Q1: {point.q1} min<br/>'\
          'Q2: {point.median} min<br/>'\
          'Q3: {point.q3} min<br/>'\
          'high: {point.high} min',
    }
}
chart.set_dict_options(options)
chart
# Out:
# Routes with largest IQR:
#                         route_id  delay_high  delay_low   delay_q1  delay_q2  \
# 45   13011-20160415132758_v40.14   29.416667 -32.766667 -14.075000 -1.416667
# 199  76003-20160512154122_v40.34   31.416667 -32.266667 -16.000000 -0.766667
# 249  95202-20160512154122_v40.34   17.166667 -26.950000 -14.050000 -3.283333
# 219  85003-20160415132758_v40.14   27.483333 -26.000000 -12.191667 -4.916667
# 221  86003-20160512154122_v40.34   28.533333 -21.766667  -9.750000 -0.900000
#
#       delay_q3      iqr  num_delays  num_realtime_runs  num_unique_trip_ids  \
# 45   14.020833  1685.75       434.0               25.0                 10.0
# 199   7.833333  1430.00      1301.0               60.0                 24.0
# 249   3.566667  1057.00       379.0               20.0                  8.0
# 219   4.658333  1011.00      1543.0               69.0                 28.0
# 221   5.666667   925.00      1217.0               63.0                 26.0
#
#     route_short_name                                  route_long_name  \
# 45               13X                     Ranui To City Centre Express
# 199              76X                   Long Bay To Mayoral Dr Express
# 249              952  Mayoral Dr To Glenfield Shops Via Coronation Rd
# 219              85X                     Torbay To Mayoral Dr Express
# 221              86X                 Browns Bay To Mayoral Dr Express
#
#      route_type  route_text_color agency_id  route_color  \
# 45            3               NaN     NZBGW          NaN
# 199           3               NaN     NZBNS          NaN
# 249           3               NaN     NZBNS          NaN
# 219           3               NaN     NZBNS          NaN
# 221           3               NaN     NZBNS          NaN
#
#                                             route_name
# 45                   13X, Ranui To City Centre Express
# 199                76X, Long Bay To Mayoral Dr Express
# 249  952, Mayoral Dr To Glenfield Shops Via Coronat...
# 219                  85X, Torbay To Mayoral Dr Express
# 221              86X, Browns Bay To Mayoral Dr Express
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;utf-8&quot; /&gt;
#         &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt;
#     &lt;/head&gt;
#     &lt;body style=&quot;margin:0;padding:0&quot;&gt;
#                 &lt;div id=&quot;container&quot; style=&quot;height:3870px;&quot;&gt;Loading....&lt;/div&gt;
#
#
#     &lt;script&gt;
#         $(function(){
#
#
#
#
#
#
#
#             Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}});
#             var option = {&quot;colors&quot;: {}, &quot;pane&quot;: {}, &quot;legend&quot;: {&quot;enabled&quot;: false}, &quot;plotOptions&quot;: {}, &quot;navigation&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Tukey box plots of stop delays by route&quot;}, &quot;tooltip&quot;: {&quot;headerFormat&quot;: &quot;&lt;b&gt;{point.key}&lt;/b&gt;&lt;br/&gt;&quot;, &quot;pointFormat&quot;: &quot;low: {point.low} min&lt;br/&gt;Q1: {point.q1} min&lt;br/&gt;Q2: {point.median} min&lt;br/&gt;Q3: {point.q3} min&lt;br/&gt;high: {point.high} min&quot;, &quot;valueDecimals&quot;: 1}, &quot;xAxis&quot;: {&quot;type&quot;: &quot;category&quot;, &quot;title&quot;: {&quot;text&quot;: &quot;Route&quot;}, &quot;labels&quot;: {&quot;step&quot;: 1}}, &quot;loading&quot;: {}, &quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;inverted&quot;: true, &quot;height&quot;: 3870}, &quot;drilldown&quot;: {}, &quot;labels&quot;: {}, &quot;exporting&quot;: {}, &quot;series&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;yAxis&quot;: {&quot;opposite&quot;: true, &quot;title&quot;: {&quot;text&quot;: &quot;Minutes&quot;}, &quot;plotLines&quot;: [{&quot;width&quot;: 2, &quot;color&quot;: &quot;red&quot;, &quot;value&quot;: 0}]}, &quot;subtitle&quot;: {&quot;text&quot;: &quot;Sample period is 20160513, 20160514, 20160515, 20160516, 20160517, 20160518, 20160519&quot;}};
#
#
#             var data = [{&quot;name&quot;: &quot;Series 1&quot;, &quot;data&quot;: [[&quot;1A, Matiatia Wharf To Onetangi Via Seaview Rd&quot;, -3.683333333333333, 1.4833333333333334, 3.25, 5.5, 11.516666666666667], [&quot;1, Ostend To Matiatia Wharf via Jellicoe Parade&quot;, -6.766666666666667, 1.3541666666666667, 3.3333333333333335, 6.85, 15.083333333333334], [&quot;2, Matiatia Wharf To Rocky Bay&quot;, -6.6, 1.6833333333333333, 3.933333333333333, 7.666666666666667, 16.616666666666667], [&quot;3, Matiatia Wharf To Rocky Bay Via Ostend &amp; Onetangi&quot;, -6.616666666666666, -1.0333333333333334, 0.6333333333333333, 2.691666666666667, 7.883333333333334], [&quot;4, Matiatia Wharf To Onetangi Direct&quot;, -3.1166666666666667, 0.95, 1.9666666666666666, 3.841666666666667, 8.166666666666666], [&quot;005, Britomart To Pt Chevalier Via Westmere&quot;, -6.666666666666667, -1.0, 0.8166666666666667, 2.841666666666667, 8.5], [&quot;007, St Heliers To Pt Chevalier Via Hospital And Selwyn Village&quot;, -9.4, 1.7666666666666666, 4.566666666666666, 9.25, 20.466666666666665], [&quot;008, Otahuhu To New Lynn&quot;, -6.75, 0.9833333333333333, 3.05, 6.15, 13.9], [&quot;009, Onehunga To New Lynn&quot;, -5.3, 0.9, 2.683333333333333, 5.05, 11.266666666666667], [&quot;010, Onehunga To Wynyard Quarter Via Unitec&quot;, -6.966666666666667, 0.75, 3.066666666666667, 5.9, 13.616666666666667], [&quot;011, St Lukes to Onehunga&quot;, -3.466666666666667, 0.9166666666666666, 2.1333333333333333, 3.933333333333333, 8.433333333333334], [&quot;020, Westmere To Britomart Via Wellington St&quot;, -5.716666666666667, -0.7166666666666667, 0.7333333333333333, 2.6166666666666667, 7.616666666666666], [&quot;020X, Britomart To Westmere Express&quot;, -5.616666666666666, -0.10833333333333334, 1.0833333333333333, 3.5791666666666666, 9.016666666666667], [&quot;030, Pt Chevalier To City Centre Via Muripara Ave&quot;, -10.316666666666666, -2.816666666666667, 0.35, 2.191666666666667, 9.666666666666666], [&quot;04X, Te Atatu Peninsula To City Centre Express&quot;, -16.45, -6.879166666666666, -1.0083333333333333, 1.1041666666666667, 11.766666666666667], [&quot;048, City Centre To Te Atatu Peninsula Complete Loop&quot;, -8.933333333333334, -2.35, 0.43333333333333335, 2.1041666666666665, 8.75], [&quot;049, Henderson to City Centre Via Te Atatu Peninsula&quot;, -9.283333333333333, -2.1791666666666667, 0.36666666666666664, 2.5833333333333335, 9.7], [&quot;060, Helensville To City Centre&quot;, -6.416666666666667, 0.2833333333333333, 2.1666666666666665, 4.770833333333333, 11.483333333333333], [&quot;070, Westgate To City Centre via Waimumu Road&quot;, -12.516666666666667, -3.9375, 0.275, 1.8666666666666667, 9.65], [&quot;07X, City Centre To Parrs Park Express Via Te Atatu South&quot;, -21.616666666666667, -12.8, -6.15, -2.05, 13.35], [&quot;079, Sturges Road To City Centre Via Sunnyvale&quot;, -17.116666666666667, -5.566666666666666, 0.008333333333333333, 2.1666666666666665, 11.85], [&quot;080, City Centre To Westgate&quot;, -7.15, -0.35, 1.4333333333333333, 4.183333333333334, 10.983333333333333], [&quot;081, Westgate To City Centre Via Don Buck Rd&quot;, -11.35, -1.9666666666666666, 1.45, 4.433333333333334, 13.566666666666666], [&quot;082, Te Atatu Shops To Westgate Shopping Centre&quot;, -9.75, -2.3583333333333334, 0.6916666666666667, 2.629166666666667, 9.35], [&quot;085, City Centre To Swanson&quot;, -13.866666666666667, -4.429166666666666, -0.016666666666666666, 1.9125, 11.2], [&quot;087, City Centre To Ranui&quot;, -9.233333333333333, -1.25, 1.15, 4.083333333333333, 12.083333333333334], [&quot;090, Henderson To Westgate Via Massey East&quot;, -10.733333333333333, -1.2625, 2.283333333333333, 5.083333333333333, 14.583333333333334], [&quot;09X, City Centre To Sturges Rd Express&quot;, -15.583333333333334, -2.933333333333333, 0.2833333333333333, 5.783333333333333, 15.4], [&quot;091, City Centre to Westgate Via Massey East and Lincoln Rd&quot;, -8.783333333333333, -0.2166666666 ...

# %%
# Select a time-of-day window
t1 = '07:00:00'
t2 = '09:00:00'

cols = ['trip_id', 'start_time', 'direction_id']
f = all_delays.copy().merge(ts[cols])

time_cond = (f['start_time'] >= t1) & (f['start_time'] <= t2)

# Separate directions
charts = []
for direction in [0, 1]:
    dir_cond = f['direction_id'] == direction
    cond = time_cond & dir_cond
    g = f.loc[cond].copy()
    g = g.groupby('route_id').apply(agg_for_box_plot).reset_index()
    g = g.merge(feed.routes)
    g.head()

    # Only keep routes with an average of at least k delay samples per sample trip
    k = 3
    cond = g['num_delays']/g['num_realtime_runs'] >= k
    g = g[cond].copy()

    # Convert to minutes
    box_cols = ['delay_low', 'delay_q1', 'delay_q2', 'delay_q3', 'delay_high']
    g[box_cols] /= 60
    g['route_name'] = g[['route_short_name', 'route_long_name']].apply(
      lambda x: ', '.join(x), axis=1) 

    # Print 10 biggest IQR routes
    print('Routes with largest IQR:')
    print(g.sort_values('iqr', ascending=False).head(5))

    # Plot
    chart = Highchart()
    data = g[['route_name'] + box_cols].copy()
    chart.add_data_set(data.values.tolist(), series_type='boxplot')
    N = data.shape[0]
    date_range = ', '.join(dates)        

    options = {
        'chart': {
            'height': 15*N,
            'inverted': True,
        },
        'plotOptions': {
        },
        'title': {
            'text': 'Tukey box plots of stop delays by route in direction {0}'.format(direction),
        },
        'subtitle': {
            'text': 'Time of day is [{0}, {1}]. <br/>Sample period is {2}'.format(
            t1, t2, date_range)
        },
        'legend': {
            'enabled': False,
        },
        'xAxis': {
            'title': {
                'text': 'Route'
            },
            'type': 'category',
            'labels': {'step': 1},
        },
        'yAxis': {
            'title': {
                'text': 'Minutes'
            },
            'opposite': True,
            'plotLines': [{
                'value': 0,
                'color': 'red',
                'width': 2,
            }]    
        },
        'tooltip': {
    #         'formatter': 'function () {\
    #             return this.point.q3 - this.point.q1 + " min"\
    #         }',
            'valueDecimals': 1,
            'headerFormat': '<b>{point.key}</b><br/>',
            'pointFormat': 'low: {point.low} min<br/>'\
              'Q1: {point.q1} min<br/>'\
              'Q2: {point.median} min<br/>'\
              'Q3: {point.q3} min<br/>'\
              'high: {point.high} min',
        }
    }
    chart.set_dict_options(options)
    charts.append(chart)

# %%
charts[0]

# %%
charts[1]

# %% [markdown]
# # Tukey box plots of end-stop delays by route

# %%
f = all_delays.copy()

# Compute trip end stop sequences
st = feed.stop_times.sort_values(['trip_id', 'stop_sequence'])
st = st.groupby('trip_id').agg('last')['stop_sequence'].reset_index()

# Get delays only for end stops
f = f.merge(st)

f.head(20)

# Aggregate by route
f = f.groupby('route_id').apply(agg_tukey).reset_index()
f = f.merge(feed.routes)

# Only keep routes with an average of at least k end-stop delays per unique trip ID
k = 2
cond = f['num_delays']/f['num_unique_trip_ids'] >= k
g = f[cond].copy()

# Convert to minutes
box_cols = ['delay_low', 'delay_q1', 'delay_q2', 'delay_q3', 'delay_high']
g[box_cols] /= 60
g['route_name'] = g[['route_short_name', 'route_long_name']].apply(
  lambda x: ', '.join(x), axis=1) 

# Print biggest IQR routes
print('Routes with largest IQR:')
print(g.sort_values('iqr', ascending=False).head(5))

# Plot
chart = Highchart()
data = g[['route_name'] + box_cols].copy()
chart.add_data_set(data.values.tolist(), series_type='boxplot')
N = data.shape[0]
date_range = ', '.join(dates)        
    
options = {
    'chart': {
        'height': 15*N,
        'inverted': True,
    },
    'plotOptions': {
    },
    'title': {
        'text': 'Tukey box plots of end-stop delays by route',
    },
    'subtitle': {
        'text': 'Sample period is {0}'.format(date_range)
    },
    'legend': {
        'enabled': False,
    },
    'xAxis': {
        'title': {
            'text': 'Route'
        },
        'type': 'category',
        'labels': {'step': 1},
    },
    'yAxis': {
        'title': {
            'text': 'Minutes'
        },
        'opposite': True,
        'plotLines': [{
            'value': 0,
            'color': 'red',
            'width': 2,
        }]    
    },
    'tooltip': {
#         'formatter': 'function () {\
#             return this.point.q3 - this.point.q1 + " min"\
#         }',
        'valueDecimals': 1,
        'headerFormat': '<b>{point.key}</b><br/>',
        'pointFormat': 'low: {point.low} min<br/>'\
          'Q1: {point.q1} min<br/>'\
          'Q2: {point.median} min<br/>'\
          'Q3: {point.q3} min<br/>'\
          'high: {point.high} min',
    }
}
chart.set_dict_options(options)
chart
# Out:
# Routes with largest IQR:
#       route_id  delay_high  delay_low   delay_q1   delay_q2   delay_q3  \
# 118  route_123   47.300000 -11.416667  -3.554167   3.783333  19.525000
# 97   route_102   30.883333 -17.033333  -6.770833   4.358333  13.929167
# 135  route_143    7.800000 -14.366667 -13.091667  -5.983333   3.700000
# 115  route_120   19.400000 -13.550000  -7.404167  -0.541667   9.337500
# 263  route_292   17.183333 -41.883333 -19.704167 -11.500000  -4.616667
#
#          iqr  num_delays  num_realtime_runs  num_unique_trip_ids  \
# 118  1384.75        18.0               18.0                  6.0
# 97   1242.00        20.0               21.0                  6.0
# 135  1007.50         8.0                8.0                  3.0
# 115  1004.50        20.0               20.0                  8.0
# 263   905.25       582.0              619.0                249.0
#
#     route_short_name                                    route_long_name  \
# 118             470X       Papakura To Britomart Express Via Redoubt Rd
# 97               344     Papatoetoe To Onehunga Via Mangere Town Centre
# 135              50F       Britomart To Otahuhu Flyer Via Mt Wellington
# 115             457X  Manukau City Centre To Britomart Express Via O...
# 263              SKY                 Airport To Downtown Via Mt Eden Rd
#
#      route_type  route_text_color agency_id  route_color  \
# 118           3               NaN     NZBWP          NaN
# 97            3               NaN     NZBWP          NaN
# 135           3               NaN     NZBWP          NaN
# 115           3               NaN     NZBWP          NaN
# 263           3               NaN     ABEXP          NaN
#
#                                             route_name
# 118  470X, Papakura To Britomart Express Via Redoub...
# 97   344, Papatoetoe To Onehunga Via Mangere Town C...
# 135  50F, Britomart To Otahuhu Flyer Via Mt Wellington
# 115  457X, Manukau City Centre To Britomart Express...
# 263            SKY, Airport To Downtown Via Mt Eden Rd
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;utf-8&quot; /&gt;
#         &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt;
#     &lt;/head&gt;
#     &lt;body style=&quot;margin:0;padding:0&quot;&gt;
#                 &lt;div id=&quot;container&quot; style=&quot;height:3315px;&quot;&gt;Loading....&lt;/div&gt;
#
#
#     &lt;script&gt;
#         $(function(){
#
#
#
#
#
#
#
#             Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}});
#             var option = {&quot;colors&quot;: {}, &quot;pane&quot;: {}, &quot;legend&quot;: {&quot;enabled&quot;: false}, &quot;plotOptions&quot;: {}, &quot;navigation&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Tukey box plots of end-stop delays by route&quot;}, &quot;tooltip&quot;: {&quot;headerFormat&quot;: &quot;&lt;b&gt;{point.key}&lt;/b&gt;&lt;br/&gt;&quot;, &quot;pointFormat&quot;: &quot;low: {point.low} min&lt;br/&gt;Q1: {point.q1} min&lt;br/&gt;Q2: {point.median} min&lt;br/&gt;Q3: {point.q3} min&lt;br/&gt;high: {point.high} min&quot;, &quot;valueDecimals&quot;: 1}, &quot;xAxis&quot;: {&quot;type&quot;: &quot;category&quot;, &quot;title&quot;: {&quot;text&quot;: &quot;Route&quot;}, &quot;labels&quot;: {&quot;step&quot;: 1}}, &quot;loading&quot;: {}, &quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;inverted&quot;: true, &quot;height&quot;: 3315}, &quot;drilldown&quot;: {}, &quot;labels&quot;: {}, &quot;exporting&quot;: {}, &quot;series&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;yAxis&quot;: {&quot;opposite&quot;: true, &quot;title&quot;: {&quot;text&quot;: &quot;Minutes&quot;}, &quot;plotLines&quot;: [{&quot;width&quot;: 2, &quot;color&quot;: &quot;red&quot;, &quot;value&quot;: 0}]}, &quot;subtitle&quot;: {&quot;text&quot;: &quot;Sample period is 20160513, 20160514, 20160515, 20160516, 20160517, 20160518, 20160519&quot;}};
#
#
#             var data = [{&quot;name&quot;: &quot;Series 1&quot;, &quot;data&quot;: [[&quot;005, Britomart To Pt Chevalier Via Westmere&quot;, -14.416666666666666, -8.016666666666667, -6.083333333333333, 1.1833333333333333, 14.433333333333334], [&quot;007, St Heliers To Pt Chevalier Via Greenlane Hospital&quot;, -14.716666666666667, -2.716666666666667, 1.6666666666666667, 6.079166666666667, 17.383333333333333], [&quot;008, New Lynn To Otahuhu&quot;, -10.516666666666667, -1.4625, 1.4583333333333333, 5.216666666666667, 13.233333333333333], [&quot;009, Sylvia Park To New Lynn Via Blockhouse Bay Shops&quot;, -13.75, -4.2, -1.2833333333333334, 2.3333333333333335, 9.866666666666667], [&quot;010, Wynyard Quarter To Onehunga Via Unitec&quot;, -18.066666666666666, -5.4125, -0.8083333333333333, 3.7875, 11.216666666666667], [&quot;011, Onehunga to St Lukes&quot;, -4.0, -1.3666666666666667, 0.4666666666666667, 3.3583333333333334, 7.316666666666666], [&quot;020, Britomart To Westmere Via Wellington St&quot;, -12.283333333333333, -3.55, -0.15833333333333333, 3.5833333333333335, 14.15], [&quot;020X, Westmere To Downtown Express&quot;, -8.666666666666666, -3.4375, -0.4583333333333333, 1.7916666666666667, 7.5], [&quot;049, Henderson to City Centre Via Te Atatu Peninsula&quot;, -16.233333333333334, -6.025, -2.05, 2.2291666666666665, 14.4], [&quot;04X, City Centre To Te Atatu Peninsula Express&quot;, -19.466666666666665, -10.254166666666666, -4.558333333333334, -0.2708333333333333, 11.766666666666667], [&quot;060, Westgate To Helensville&quot;, -18.6, -7.3625, -3.325, 0.7375, 6.516666666666667], [&quot;070, Westgate To City Centre via Waimumu Road&quot;, -18.833333333333332, -13.770833333333334, -9.458333333333334, -5.0, 2.683333333333333], [&quot;079, City Centre To Sturges Road Via Sunnyvale&quot;, -18.8, -6.816666666666666, -3.716666666666667, 1.8583333333333334, 4.466666666666667], [&quot;07X, City Centre To Parrs Park Express Via Te Atatu South&quot;, -21.533333333333335, -13.8, -7.966666666666667, -2.433333333333333, 9.683333333333334], [&quot;081, City Centre To Westgate Via Don Buck Rd&quot;, -14.633333333333333, -8.566666666666666, -6.533333333333333, 0.36666666666666664, 10.8], [&quot;082, Te Atatu Shops To Westgate Shopping Centre&quot;, -17.616666666666667, -17.033333333333335, -11.933333333333334, -3.9, -3.9], [&quot;085, Swanson To City Centre&quot;, -15.216666666666667, -10.183333333333334, -6.0, -2.7333333333333334, 1.0166666666666666], [&quot;087, City Centre To Ranui&quot;, -18.033333333333335, -7.404166666666667, -3.533333333333333, 3.3208333333333333, 18.583333333333332], [&quot;090, Westgate To City Centre Via Massey East&quot;, -26.633333333333333, -12.3, -5.9, -0.5, 15.3], [&quot;091, City Centre to Westgate Via Massey East and Lincoln Rd&quot;, -16.45, -9.333333333333334, -0.6666666666666666, 4.770833333333333, 5.233333333333333], [&quot;092, Westgate To Hobsonville&quot;, -15.566666666666666, -7.816666666666666, -4.983333333333333, -1.2333333333333334, 7.05], [&quot;093, Whenuapai To Westgate Via Hobsonville Wharf&quot;, -10.616666666666667, -6.225, -4.266666666666667, 2.225, 9.383333333333333], [&quot;095, Whenuapai To City Centre&quot;, -15.5, -13.1, -11.425, -10.195833333333333, -9.133333333333333], [&quot;097, City Centre To Ranui Via Te Atatu South&quot;, -25.45, -14.104166666666666, -5.333333333333333, 0.19583333333333333, 13.683333333333334], [&quot;09X, Sturges Rd To City Centre Express&quot;, -11.316666666666666, -5.75, -2.8, -1.05, 4.566666666666666], [&quot;102, New Lynn To Patiki Rd Via Rosebank Rd&quot;, -8.683333333333334, -3.6166666666666667, -1.3833333333333333, 1.9833333333333334, 8.95], [&quot;113, New Lynn To Henderson Via Great North Rd&quot;, -18.0, -5.4, -1.4666666666666666, 3.1416666666666666, 9.916666666666666], [&quot;115, Henderson To New Lynn Via Glendene&quot;, -20.4, -6.383333333333334, -2.45, 3.0416666666666665, 15.466666666666667], [&quot;11X, City Centre To Henderson Express Via Glendene&qu ...

# %% [markdown]
# # Explore percentage of punctual trips by route

# %%
# Say that a trip is k-punctual if it arrives no more than
# k seconds late at its final stop

k = 5*60

# Get trip final delays
def final_delay(group):
    d = dict()
    d['final_delay'] = group['arrival_delay'].iat[-1]
    return pd.Series(d)

f = st.copy()
f = f.sort_values(['trip_id', 'stop_sequence']).groupby('trip_id').apply(
  final_delay).reset_index()
f = f.merge(ts)

# Calculate fraction of k-punctual trips for each route
def fpt(group):
    d = dict()
    n = group['final_delay'].count()
    cond = group['final_delay'] <= k
    d['frac_punctual_trips'] = group.loc[cond, 'final_delay'].shape[0]/n
    d['num_samples'] = n
    return pd.Series(d)

f = f.groupby('route_id').apply(fpt).reset_index()
f = f.merge(rs)
f['frac_samples'] = f['num_samples']/f['num_trips']
f.sort_values('frac_punctual_trips').head(10)

# %%
# Plot some

# Only keep routes with at least half of trips sampled
cond = f['frac_samples'] >= 0.5
g = f[cond].copy()
g['route_name'] = g[['route_short_name', 'route_long_name']].apply(
  lambda x: ', '.join(x), axis=1) 
g['ppt'] = g['frac_punctual_trips']*100

chart = Highchart()
data = g[['route_name', 'ppt']].copy()
chart.add_data_set(data.values.tolist(), series_type='bar')
N = data.shape[0]
        
options = {
    'chart': {
        'height': 15*N,
    },
    'plotOptions': {
        'series': {
            'minPointLength': 3,
        },
    },
    'title': {
        'text': 'Percentage of 5-minute-punctual trips by route',
    },
    'subtitle': {
        'text': 'Sample period is {0}'.format(date)
    },
    'legend': {
        'enabled': False,
    },
    'xAxis': {
        'title': {
            'text': 'Route'
        },
        'type': 'category',
        'labels': {'step': 1},
    },
    'yAxis': {
        'title': {
            'text': 'Percentage'
        },
        'opposite': True,
        'max': 100,
    },
    'tooltip': {
        'headerFormat': '<b>{point.key}</b><br/>',
        'pointFormat': '{point.y}%',
        'valueDecimals': 0,
    }
}
chart.set_dict_options(options)
chart

# %%
# # Fill departure delays.

# # 1. First pass. 
# # Fill actual departure times via distance interpolation.
# # Then use these to fill departure delays.
# f = st.copy()

# print('num trips=', f['trip_id'].nunique())

# f['actual_departure_time'] = f['departure_time'].map(gt.timestr_to_seconds) +\
#   f['departure_delay']

# def fill_dtimes(group):
#     indices = np.where(group['actual_departure_time'].notnull())[0]
#     if not indices.size:
#         return group
#     times = group['actual_departure_time'].ix[indices]
#     dists = group['shape_dist_traveled'].ix[indices]
#     ds = group['shape_dist_traveled']
#     ts = np.interp(ds, dists, times)
#     group['actual_departure_time'] = ts
#     return group

# f = f.groupby('trip_id').apply(fill_dtimes)

# # Round departure times
# f['actual_departure_time'] = f['actual_departure_time'].round()

# # Compute delays
# f['departure_delay'] = f['actual_departure_time'] -\
#   f['arrival_time'].map(gt.timestr_to_seconds)
    

# # 2. Second pass. 
# # For the remaining null departure delays, fill them by forward fill
# # and then backward fill.
# f['departure_delay'] = f['departure_delay'].fillna(method='ffill').fillna(method='bfill')     

# f['actual_departure_time'] = f['departure_time'].map(gt.timestr_to_seconds) +\
#   f['departure_delay']

# # Convert back to time strings
# f['actual_departure_time'] = f['actual_departure_time'].map(
#   lambda x: gt.timestr_to_seconds(x, inverse=True))

# f.T
